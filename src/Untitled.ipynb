# %%
using Plots
using LaTeXStrings

# %%
plot([1],[1],ylabel=L"\mathcal{I J}")

# %%
plot([1],[1],ylabel=L"1",yguidefont="Bookman")

# %%
default(;fontfamily="Bookman"); plot([1],[1],ylabel=L"\mathcal{I}")

# %%
default(;fontfamily="Bookman"); plot([1],[1],xlabel="",ylabel=L"")

# %%
#default(;fontfamily="Roman");
#using Plots
#using LaTeXStrings
#plot([1],[1],ylabel="𝓘",ylabel=string("1𝓘\$1\$"))
default(;fontfamily="Times Roman");
plot([1],[1],ylabel="𝓘")

# %%
default(;fontfamily="Times Roman"); plot([1],[1],ylabel=string("𝓘",L"1"))

# %%
default(;fontfamily="Times Roman"); plot([1],[1],ylabel=L"\textrm{𝓘}")

# %%
default(;fontfamily="Times Roman");
plot([1],[1],ylabel=string("𝓘\$1\$"))

# %%
string("𝓘",latexstring("I"))

# %%
default(;fontfamily="");
plot( title=L"\mathrm{𝓘}" )

# %%
Plots.font("DejaVuSans")

# %%
plotfonts = Plots.font(40, "")
plot([1], [1], title="Helvetica 4ever", titlefont = plotfonts)

# %%
GR.fonts

# %%
GR.jlgr.fonts["Times_Roman"]

# %%
GR.grdir

# %%
collect(keys(ENV))[end-40:end-20]

# %%
collect(keys(ENV))[end-20:end]

# %%
ENV["FONTCONFIG_FILE"]

# %%
using Pkg

# %%
Pkg.add("Plots")

# %%
Pkg.status()

# %%
Pkg.update("LaTeXStrings")

# %%
Pkg.status()
